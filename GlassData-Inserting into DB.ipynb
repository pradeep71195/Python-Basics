# %%
#Install Pandas (if not already installed)
#pip install pandas
# Out:
# ...
#      |████████████████████████████████| 12.2 MB 22.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 17.3 MB 56.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 499 kB 69.2 MB/s eta 0:00:01
# ...
#   WARNING: The scripts f2py, f2py3 and f2py3.8 are installed in '/config/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#
# Read the Glass.data file
# Insert all the records into MySQL DB
#
import pandas as pd

# %%
# Read file
input_file = pd.read_csv('glass.data', sep=',')
print(input_file)
# Out:
#      index       RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Class
# 0        1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0      1
# 1        2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0      1
# 2        3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0      1
# 3        4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0      1
# 4        5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0      1
# ..     ...      ...    ...   ...   ...    ...   ...   ...   ...  ...    ...
# 209    210  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0      7
# 210    211  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0      7
# 211    212  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0      7
# 212    213  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0      7
# 213    214  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0      7
#
# [214 rows x 11 columns]

# %%
# Establish DB connection

import mysql.connector
# import mysql.connector
#create user 'user'@'%' identified by 'password'
mydb = mysql.connector.connect(
  host="localhost",
  user="abc",
  password="password"
)
print(mydb)
mycursor = mydb.cursor()
mycursor.execute("SHOW DATABASES")
for i in mycursor:
  print(i)
# Out:
# ...
# ('information_schema',)
# ('mysql',)
# ('performance_schema',)
# ('sys',)

# %%
#mycursor.execute("CREATE DATABASE myTestDB")

# %%
#mycursor.execute("Use myTestDB")

# %%
#mycursor.execute('CREATE Table GlassData (Index1 int, RI varchar(10), Na varchar(10), Mg varchar(10), Al varchar(10), Si varchar(10), K varchar(10), Ca varchar(10), Ba varchar(10), Fe varchar(10), Class varchar(10));')

# %%
#Insert all the rows into the DB Table

for row in input_file.index:
    print(f"inserting row - {row}")
    mycursor.execute(f"""INSERT INTO GlassData VALUES ({input_file['index'][row]}, {input_file['RI'][row]}, 
    {input_file['Na'][row]}, {input_file['Mg'][row]}, {input_file['Al'][row]}, {input_file['Si'][row]}, 
    {input_file['K'][row]}, {input_file['Ca'][row]}, {input_file['Ba'][row]}, {input_file['Fe'][row]}, 
    {input_file['Class'][row]})""")
    mydb.commit()
    print("Row Inserted Successfully")
    print("-------------------------")
print("Process Completed. Check DB.")
# Out:
# inserting row - 0
# Row Inserted Successfully
# -------------------------
# inserting row - 1
# Row Inserted Successfully
# -------------------------
# inserting row - 2
# Row Inserted Successfully
# -------------------------
# inserting row - 3
# Row Inserted Successfully
# -------------------------
# inserting row - 4
# Row Inserted Successfully
# -------------------------
# inserting row - 5
# Row Inserted Successfully
# -------------------------
# inserting row - 6
# Row Inserted Successfully
# -------------------------
# inserting row - 7
# Row Inserted Successfully
# -------------------------
# inserting row - 8
# Row Inserted Successfully
# -------------------------
# inserting row - 9
# Row Inserted Successfully
# -------------------------
# inserting row - 10
# Row Inserted Successfully
# -------------------------
# inserting row - 11
# Row Inserted Successfully
# -------------------------
# inserting row - 12
# Row Inserted Successfully
# -------------------------
# ...
